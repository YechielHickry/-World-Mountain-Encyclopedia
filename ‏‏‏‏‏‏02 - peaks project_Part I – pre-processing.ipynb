# %% [markdown]
# # <span style="color: navy"> Project #2 – DS Tools </span>

# %% [markdown]
# ### <span style="color: navy"> Background </span>

# %% [markdown]
# In this project we will explore and visualize some facts about mountains and peaks around the world.
# The project is entirely based on the data available in the site PeakWare.com,
# which entitles itself as the “World Mountain Encyclopedia”.

# %% [markdown]
# # <span style="color: green">Part I – pre-processing</navy>

# %%
import re
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from time import time
from datetime import datetime

from mpl_toolkits.basemap import Basemap
# import networkx as nx

matplotlib.style.use('ggplot')

# %matplotlib inline
# %matplotlib notebook
# i use the notebook parameter instead of in line in order to zoom in the graphs using matplotlib
from os import getcwd
pd.set_option('notebook_repr_html', True)

# %% [markdown]
# #### Jupyter will display all variable without the need for a print statement and not only the last

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# this limit the column width
pd.options.display.max_colwidth = 20
# this controls the floating rounding (precision, keep 2 decimals after .)
pd.options.display.precision =2

# %% [markdown]
# ### <span style="color: navy  ">General Functions</span>

# %%
def print_tag (tags) :
    for i,tag in enumerate(tags, start=0):
        print "***{:03}***".format(i),
        print str(tag).replace('\n', '').strip(),
        
def extract_tag_string(tag_tr,name):
    return unicode(tag_tr.find(name='td').string) if name in str(tag_tr) else None

# %% [markdown]
# ### <span style="color: navy  ">Extracting continents list</span>

# %% [markdown]
# In the next block, we access [peakware.com][1].
# Extracting the continents list.
# This list will  allow us to extract the entire peaks code list
# [1]: https://www.peakware.com/peaks.php "peakware.com"

# %%
# url: It is the website/page you want to open.
url = "https://www.peakware.com/peaks.php"
# Getting the webpage, creating a Response object.
resp = requests.get(url)
# Extracting the source code of the page.
data = resp.text
# Passing the source code to Beautiful Soup to create a BeautifulSoup object for it.
soup = bs(data, 'lxml')

# %% [markdown]
# ##### 1st way with split

# %%
continents_list=[]
attr= {'id':'contList'}
continents_tags= soup.find(name ='ul',attrs=attr).find_all(name ='li')
# print_tag (continents_tags) 
continents_list =[(str((tag.a)).split('choice=')[1]).split('">')[0] for tag in continents_tags]
continents_list
# Out:
# ['AfA', 'AnA', 'AsA', 'AuA', 'EuA', 'NoA', 'SoA']

# %% [markdown]
# ##### 2ns way with re

# %%
cont_list=[]
continents_tags = soup.find_all('a')
for tag in continents_tags:
    x = re.findall('href="peaks.php\?choice=\w{3}',str(tag))
    if len (x) :
        cont_list.append(x)
cont_list2 = [str(continent)[-5:-2]  for continent in cont_list [::2]]
cont_list2
# Out:
# ['AfA', 'AnA', 'AsA', 'AuA', 'EuA', 'NoA', 'SoA']

# %% [markdown]
# ### <span style="color: indigo ">Extracting peak list</span>

# %% [markdown]
# IIn the next block, we will iterate through continents list, in order to create "peaks_code_list"

# %%
peaks_code_list = []
for continent in continents_list:
    url_continents = 'https://www.peakware.com/peaks.php'+'?choice='+continent
    resp = requests.get(url_continents)
    soup = bs(resp.text, 'lxml')
    peaks_tags = soup.find(name='ul', id='peakList').find_all(name ='li')
    # print_tag(peaks_tags)
    peaks_code_list.extend([(str((tag.a)).split('php?pk=')[1]).split('">')[0] for tag in peaks_tags])
print len (peaks_code_list)
# Out:
# 4194

# %% [markdown]
# ### <span style="color: indigo">Main - Extracting peaks sttributes</span>

# %% [markdown]
# In the next block, we will iterate through "peaks_code_list".
# accessing each web page and extracting each peak attribute and the value (including "peak name" and "peak code").
# The data will be inserted into a dictionary, which will pe append to a data frame.
# At the end, all data will be exported to a CSV file

# %%
# main 1st
df = pd.DataFrame()
df_temp = pd.DataFrame()
peaks_df_list = []
t_1 = time()

for i,peak in enumerate(peaks_code_list, start=0):
    temp_peak_dict = dict()
    print "{:05} - peak code : {} ".format (i,peak)   
     
    url_peak = 'https://www.peakware.com/peaks.php?pk='+peak
    try:
        resp = requests.get(url_peak)
    except requests.exceptions.ConnectionError:
        r.status_code = "Connection refused"
    soup = bs(resp.text, 'lxml')
    
    #     initialize the 1st attribute peak_code
    temp_peak_dict['peak_code']=str(peak) # update
    #     initialize the 2nd attribute name_of_peak
    temp_peak_dict['name_of_peak'] = unicode(soup.find(name='h1').string)

    #     initialize the rest of the attributes depending on the tags available
    tags = soup.find(name='table').find_all(name ='tr')   
#     print_tag(tags)
    
    for tag_tr in tags :
        temp_peak_dict[str(tag_tr.find(name='th').string).strip()] = unicode(tag_tr.find(name='td').string)
    
#     append the new dictionary as a raw in the dataframe
    df = df.append(temp_peak_dict, ignore_index=True)

#     timing the ruuning time
t_2 = time()
print "it took  {:.3f} seconds".format(t_2-t_1)

# it took  4321.018 seconds
# it took  42.908 seconds
# it took  33.116 seconds
# it took  29.796 seconds
# it took  27.725 seconds
# it took  4073.604 seconds
# Out:
# 00000 - peak code : 1387
# 00001 - peak code : 2483
# 00002 - peak code : 3122
# 00003 - peak code : 23
# 00004 - peak code : 2382
# 00005 - peak code : 2133
# 00006 - peak code : 4543
# 00007 - peak code : 37
# 00008 - peak code : 40
# 00009 - peak code : 1937
# 00010 - peak code : 1566
# 00011 - peak code : 993
# 00012 - peak code : 74
# 00013 - peak code : 147
# 00014 - peak code : 76
# 00015 - peak code : 1100
# 00016 - peak code : 93
# 00017 - peak code : 1971
# 00018 - peak code : 2167
# 00019 - peak code : 1356
# 00020 - peak code : 2207
# 00021 - peak code : 666
# 00022 - peak code : 681
# 00023 - peak code : 4544
# 00024 - peak code : 1373
# 00025 - peak code : 4545
# 00026 - peak code : 768
# 00027 - peak code : 1758
# 00028 - peak code : 2165
# 00029 - peak code : 1035
# 00030 - peak code : 135
# 00031 - peak code : 139
# 00032 - peak code : 4253
# 00033 - peak code : 1429
# 00034 - peak code : 1905
# 00035 - peak code : 3361
# 00036 - peak code : 1908
# 00037 - peak code : 788
# 00038 - peak code : 2205
# 00039 - peak code : 160
# 00040 - peak code : 2970
# 00041 - peak code : 3236
# 00042 - peak code : 3398
# 00043 - peak code : 545
# 00044 - peak code : 2084
# 00045 - peak code : 177
# 00046 - peak code : 4453
# 00047 - peak code : 183
# 00048 - peak code : 2017
# 00049 - peak code : 186
# 00050 - peak code : 2784
# 00051 - peak code : 1109
# 00052 - peak code : 85
# 00053 - peak code : 192
# 00054 - peak code : 1272
# 00055 - peak code : 215
# 00056 - peak code : 1386
# 00057 - peak code : 235
# 00058 - peak code : 397
# 00059 - peak code : 1101
# 00060 - peak code : 2335
# 00061 - peak code : 1084
# 00062 - peak code : 245
# 00063 - peak code : 398
# 00064 - peak code : 246
# 00065 - peak code : 2391
# 00066 - peak code : 1385
# 00067 - peak code : 253
# 00068 - peak code : 1658
# 00069 - peak code : 4533
# 00070 - peak code : 396
# 00071 - peak code : 4148
# 00072 - peak code : 3329
# 00073 - peak code : 77
# 00074 - peak code : 3679
# 00075 - peak code : 4147
# 00076 - peak code : 4146
# 00077 - peak code : 3180
# 00078 - peak code : 4149
# 00079 - peak code : 4152
# 00080 - peak code : 4586
# 00081 - peak code : 4150
# 00082 - peak code : 4155
# 00083 - peak code : 994
# 00084 - peak code : 2321
# 00085 - peak code : 2911
# 00086 - peak code : 4013
# 00087 - peak code : 2495
# 00088 - peak code : 1070
# 00089 - peak code : 4370
# 00090 - peak code : 4185
# 00091 - peak code : 4270
# 00092 - peak code : 2215
# 00093 - peak code : 3845
# 00094 - peak code : 1770
# 00095 - peak code : 2937
# 00096 - peak code : 449
# 00097 - peak code : 2825
# 00098 - peak code : 2718
# 00099 - peak code : 2789
# 00100 - peak code : 9
# 00101 - peak code : 10
# 00102 - peak code : 2668
# 00103 - peak code : 1354
# 00104 - peak code : 13
# 00105 - peak code : 724
# 00106 - peak code : 1918
# 00107 - peak code : 4028
# 00108 - peak code : 14
# 00109 - peak code : 1397
# 00110 - peak code : 3847
# 00111 - peak code : 279
# 00112 - peak code : 2134
# 00113 - peak code : 2545
# 00114 - peak code : 4455
# 00115 - peak code : 2815
# 00116 - peak code : 1160
# 00117 - peak code : 4011
# 00118 - peak code : 1614
# 00119 - peak code : 2995
# 00120 - peak code : 2008
# 00121 - peak code : 2909
# 00122 - peak code : 2883
# 00123 - peak code : 3348
# 00124 - peak code : 890
# 00125 - peak code : 4014
# 00126 - peak code : 3162
# 00127 - peak code : 2639
# 00128 - peak code : 2659
# 00129 - peak code : 3877
# 00130 - peak code : 2683
# 00131 - peak code : 3183
# 00132 - peak code : 3471
# 00133 - peak code : 737
# 00134 - peak code : 3980
# 00135 - peak code : 3177
# 00136 - peak code : 533
# 00137 - peak code : 2764
# 00138 - peak code : 1261
# 00139 - peak code : 2507
# 00140 - peak code : 2612
# 00141 - peak code : 2715
# 00142 - peak code : 4269
# 00143 - peak code : 4355
# 00144 - peak code : 32
# 00145 - peak code : 1601
# 00146 - peak code : 389
# 00147 - peak code : 2901
# 00148 - peak code : 2843
# 00149 - peak code : 4278
# 00150 - peak code : 2632
# 00151 - peak code : 38
# 00152 - peak code : 974
# 00153 - peak code : 3965
# 00154 - peak code : 897
# 00155 - peak code : 4163
# 00156 - peak code : 797
# 00157 - peak code : 672
# 00158 - peak code : 836
# 00159 - peak code : 1092
# 00160 - peak code : 655
# 00161 - peak code : 2755
# 00162 - peak code : 654
# 00163 - peak code : 941
# 00164 - peak code : 1930
# 00165 - peak code : 3634
# 00166 - peak code : 43
# 00167 - peak code : 3213
# 00168 - peak code : 1719
# 00169 - peak code : 2204
# 00170 - peak code : 4275
# 00171 - peak code : 60
# 00172 - peak code : 1676
# 00173 - peak code : 2466
# 00174 - peak code : 1143
# 00175 - peak code : 4010
# 00176 - peak code : 4360
# 00177 - peak code : 2674
# 00178 - peak code : 284
# 00179 - peak code : 1705
# 00180 - peak code : 2325
# 00181 - peak code : 2838
# 00182 - peak code : 63
# 00183 - peak code : 4267
# 00184 - peak code : 2821
# 00185 - peak code : 2751
# 00186 - peak code : 64
# 00187 - peak code : 3983
# 00188 - peak code : 1547
# 00189 - peak code : 1227
# 00190 - peak code : 978
# 00191 - peak code : 803
# 00192 - peak code : 2676
# 00193 - peak code : 289
# 00194 - peak code : 2009
# 00195 - peak code : 75
# 00196 - peak code : 4356
# 00197 - peak code : 285
# 00198 - peak code : 4012
# 00199 - peak code : 80
# 00200 - peak code : 2478
# 00201 - peak code : 2708
# 00202 - peak code : 541
# 00203 - peak code : 4358
# 00204 - peak code : 86
# 00205 - peak code : 2803
# 00206 - peak code : 88
# 00207 - peak code : 4596
# 00208 - peak code : 4133
# 00209 - peak code : 2490
# 00210 - peak code : 1058
# 00211 - peak code : 626
# 00212 - peak code : 668
# 00213 - peak code : 652
# 00214 - peak code : 1050
# 00215 - peak code : 4276
# 00216 - peak code : 3248
# 00217 - peak code : 2831
# 00218 - peak code : 1733
# 00219 - peak code : 3904
# 00220 - peak code : 847
# 00221 - peak code : 842
# 00222 - peak code : 2095
# 00223 - peak code : 28
# 00224 - peak code : 767
# 00225 - peak code : 2769
# 00226 - peak code : 1771
# 00227 - peak code : 4291
# 00228 - peak code : 2935
# 00229 - peak code : 3341
# 00230 - peak code : 2228
# 00231 - peak code : 2087
# 00232 - peak code : 2181
# 00233 - peak code : 3974
# 00234 - peak code : 3020
# 00235 - peak code : 1857
# 00236 - peak code : 3973
# 00237 - peak code : 2021
# 00238 - peak code : 2088
# 00239 - peak code : 175
# 00240 - peak code : 2189
# 00241 - peak code : 1923
# 00242 - peak code : 2091
# 00243 - peak code : 443
# 00244 - peak code : 310
# 00245 - peak code : 2752
# 00246 - peak code : 1240
# 00247 - peak code : 873
# 00248 - peak code : 3972
# 00249 - peak code : 2183
# 00250 - peak code : 1917
# 00251 - peak code : 976
# 00252 - peak code : 103
# 00253 - peak code : 3021
# 00254 - peak code : 2361
# 00255 - peak code : 1734
# 00256 - peak code : 1398
# 00257 - peak code : 2472
# 00258 - peak code : 4286
# 00259 - peak code : 2527
# 00260 - peak code : 2570
# 00261 - peak code : 2102
# 00262 - peak code : 2812
# 00263 - peak code : 2141
# 00264 - peak code : 3466
# 00265 - peak code : 1148
# 00266 - peak code : 1713
# 00267 - peak code : 1036
# 00268 - peak code : 991
# 00269 - peak code : 916
# 00270 - peak code : 529
# 00271 - peak code : 3147
# 00272 - peak code : 3844
# 00273 - peak code : 2700
# 00274 - peak code : 2936
# 00275 - peak code : 52
# 00276 - peak code : 444
# 00277 - peak code : 2813
# 00278 - peak code : 1927
# 00279 - peak code : 3385
# 00280 - peak code : 3736
# 00281 - peak code : 868
# 00282 - peak code : 845
# 00283 - peak code : 437
# 00284 - peak code : 2798
# 00285 - peak code : 2288
# 00286 - peak code : 2947
# 00287 - peak code : 3702
# 00288 - peak code : 3146
# 00289 - peak code : 1357
# 00290 - peak code : 2771
# 00291 - peak code : 3165
# 00292 - peak code : 2918
# 00293 - peak code : 129
# 00294 - peak code : 2104
# 00295 - peak code : 1137
# 00296 - peak code : 603
# 00297 - peak code : 130
# 00298 - peak code : 1384
# 00299 - peak code : 4302
# 00300 - peak code : 1591
# 00301 - peak code : 2835
# 00302 - peak code : 3327
# 00303 - peak code : 131
# 00304 - peak code : 3848
# 00305 - peak code : 954
# 00306 - peak code : 540
# 00307 - peak code : 2103
# 00308 - peak code : 2460
# 00309 - peak code : 132
# 00310 - peak code : 2461
# 00311 - peak code : 1889
# 00312 - peak code : 3825
# 00313 - peak code : 1078
# 00314 - peak code : 4141
# 00315 - peak code : 903
# 00316 - peak code : 2826
# 00317 - peak code : 3618
# 00318 - peak code : 2822
# 00319 - peak code : 3312
# 00320 - peak code : 1029
# 00321 - peak code : 927
# 00322 - peak code : 3145
# 00323 - peak code : 1751
# 00324 - peak code : 2806
# 00325 - peak code : 3116
# 00326 - peak code : 1031
# 00327 - peak code : 1732
# 00328 - peak code : 137
# 00329 - peak code : 3808
# 00330 - peak code : 820
# 00331 - peak code : 4016
# 00332 - peak code : 138
# 00333 - peak code : 1546
# 00334 - peak code : 328
# 00335 - peak code : 3481
# 00336 - peak code : 849
# 00337 - peak code : 4588
# 00338 - peak code : 1027
# 00339 - peak code : 2877
# 00340 - peak code : 2951
# 00341 - peak code : 142
# 00342 - peak code : 2827
# 00343 - peak code : 143
# 00344 - peak code : 1275
# 00345 - peak code : 3246
# 00346 - peak code : 144
# 00347 - peak code : 925
# 00348 - peak code : 1174
# 00349 - peak code : 148
# 00350 - peak code : 2398
# 00351 - peak code : 2058
# 00352 - peak code : 149
# 00353 - peak code : 624
# 00354 - peak code : 4695
# 00355 - peak code : 957
# 00356 - peak code : 867
# 00357 - peak code : 2418
# 00358 - peak code : 3616
# 00359 - peak code : 3617
# 00360 - peak code : 4037
# 00361 - peak code : 3704
# 00362 - peak code : 1677
# 00363 - peak code : 4131
# 00364 - peak code : 4130
# 00365 - peak code : 1853
# 00366 - peak code : 4257
# 00367 - peak code : 3048
# 00368 - peak code : 3393
# 00369 - peak code : 153
# 00370 - peak code : 773
# 00371 - peak code : 778
# 00372 - peak code : 850
# 00373 - peak code : 3608
# 00374 - peak code : 930
# 00375 - peak code : 158
# 00376 - peak code : 2378
# 00377 - peak code : 1224
# 00378 - peak code : 3159
# 00379 - peak code : 3535
# 00380 - peak code : 3209
# 00381 - peak code : 4187
# 00382 - peak code : 3828
# 00383 - peak code : 162
# 00384 - peak code : 4285
# 00385 - peak code : 2040
# 00386 - peak code : 4229
# 00387 - peak code : 2817
# 00388 - peak code : 2647
# 00389 - peak code : 3977
# 00390 - peak code : 4259
# 00391 - peak code : 164
# 00392 - peak code : 777
# 00393 - peak code : 776
# 00394 - peak code : 4255
# 00395 - peak code : 4282
# 00396 - peak code : 4271
# 00397 - peak code : 4279
# 00398 - peak code : 4281
# 00399 - peak code : 2322
# 00400 - peak code : 4295
# 00401 - peak code : 3461
# 00402 - peak code : 2818
# 00403 - peak code : 167
# 00404 - peak code : 1559
# 00405 - peak code : 985
# 00406 - peak code : 2423
# 00407 - peak code : 2829
# 00408 - peak code : 1198
# 00409 - peak code : 908
# 00410 - peak code : 4546
# 00411 - peak code : 454
# 00412 - peak code : 3856
# 00413 - peak code : 180
# 00414 - peak code : 4423
# 00415 - peak code : 1349
# 00416 - peak code : 2544
# 00417 - peak code : 2014
# 00418 - peak code : 2200
# 00419 - peak code : 970
# 00420 - peak code : 4124
# 00421 - peak code : 1939
# 00422 - peak code : 187
# 00423 - peak code : 188
# 00424 - peak code : 2765
# 00425 - peak code : 2318
# 00426 - peak code : 2320
# 00427 - peak code : 4357
# 00428 - peak code : 1033
# 00429 - peak code : 189
# 00430 - peak code : 190
# 00431 - peak code : 2734
# 00432 - peak code : 4167
# 00433 - peak code : 2691
# 00434 - peak code : 191
# 00435 - peak code : 4440
# 00436 - peak code : 3161
# 00437 - peak code : 1515
# 00438 - peak code : 1947
# 00439 - peak code : 2608
# 00440 - peak code : 4551
# 00441 - peak code : 2875
# 00442 - peak code : 876
# 00443 - peak code : 775
# 00444 - peak code : 1441
# 00445 - peak code : 2753
# 00446 - peak code : 885
# 00447 - peak code : 195
# 00448 - peak code : 196
# 00449 - peak code : 931
# 00450 - peak code : 2019
# 00451 - peak code : 4372
# 00452 - peak code : 201
# 00453 - peak code : 4437
# 00454 - peak code : 1835
# 00455 - peak code : 894
# 00456 - peak code : 2661
# 00457 - peak code : 4483
# 00458 - peak code : 2737
# 00459 - peak code : 3149
# 00460 - peak code : 3835
# 00461 - peak code : 2809
# 00462 - peak code : 693
# 00463 - peak code : 2301
# 00464 - peak code : 645
# 00465 - peak code : 1245
# 00466 - peak code : 1465
# 00467 - peak code : 2208
# 00468 - peak code : 4290
# 00469 - peak code : 1864
# 00470 - peak code : 2873
# 00471 - peak code : 2642
# 00472 - peak code : 639
# 00473 - peak code : 638
# 00474 - peak code : 152
# 00475 - peak code : 4415
# 00476 - peak code : 1013
# 00477 - peak code : 324
# 00478 - peak code : 997
# 00479 - peak code : 1458
# 00480 - peak code : 2728
# 00481 - peak code : 723
# 00482 - peak code : 2758
# 00483 - peak code : 905
# 00484 - peak code : 1378
# 00485 - peak code : 2079
# 00486 - peak code : 989
# 00487 - peak code : 1995
# 00488 - peak code : 4162
# 00489 - peak code : 1303
# 00490 - peak code : 2662
# 00491 - peak code : 214
# 00492 - peak code : 740
# 00493 - peak code : 789
# 00494 - peak code : 1855
# 00495 - peak code : 918
# 00496 - peak code : 1274
# 00497 - peak code : 4195
# 00498 - peak code : 1097
# 00499 - peak code : 4549
# 00500 - peak code : 3958
# 00501 - peak code : 3035
# 00502 - peak code : 2216
# 00503 - peak code : 3898
# 00504 - peak code : 3163
# 00505 - peak code : 4181
# 00506 - peak code : 1867
# 00507 - peak code : 1069
# 00508 - peak code : 3846
# 00509 - peak code : 2105
# 00510 - peak code : 3032
# 00511 - peak code : 227
# 00512 - peak code : 1564
# 00513 - peak code : 901
# 00514 - peak code : 3829
# 00515 - peak code : 230
# 00516 - peak code : 1552
# 00517 - peak code : 2808
# 00518 - peak code : 1218
# 00519 - peak code : 2575
# 00520 - peak code : 1110
# 00521 - peak code : 913
# 00522 - peak code : 1662
# 00523 - peak code : 2740
# 00524 - peak code : 2739
# 00525 - peak code : 2541
# 00526 - peak code : 2766
# 00527 - peak code : 1004
# 00528 - peak code : 3344
# 00529 - peak code : 2220
# 00530 - peak code : 327
# 00531 - peak code : 1003
# 00532 - peak code : 1631
# 00533 - peak code : 4258
# 00534 - peak code : 4256
# 00535 - peak code : 801
# 00536 - peak code : 1836
# 00537 - peak code : 2480
# 00538 - peak code : 2323
# 00539 - peak code : 3517
# 00540 - peak code : 3157
# 00541 - peak code : 3414
# 00542 - peak code : 810
# 00543 - peak code : 1862
# 00544 - peak code : 244
# 00545 - peak code : 560
# 00546 - peak code : 2720
# 00547 - peak code : 3484
# 00548 - peak code : 1545
# 00549 - peak code : 2792
# 00550 - peak code : 4266
# 00551 - peak code : 3077
# 00552 - peak code : 2858
# 00553 - peak code : 2950
# 00554 - peak code : 2823
# 00555 - peak code : 4186
# 00556 - peak code : 2435
# 00557 - peak code : 734
# 00558 - peak code : 3981
# 00559 - peak code : 1720
# 00560 - peak code : 485
# 00561 - peak code : 3240
# 00562 - peak code : 1483
# 00563 - peak code : 3596
# 00564 - peak code : 1837
# 00565 - peak code : 969
# 00566 - peak code : 4284
# 00567 - peak code : 4283
# 00568 - peak code : 252
# 00569 - peak code : 1335
# 00570 - peak code : 4116
# 00571 - peak code : 255
# 00572 - peak code : 2450
# 00573 - peak code : 4359
# 00574 - peak code : 695
# 00575 - peak code : 4367
# 00576 - peak code : 720
# 00577 - peak code : 2538
# 00578 - peak code : 2568
# 00579 - peak code : 1180
# 00580 - peak code : 4007
# 00581 - peak code : 1992
# 00582 - peak code : 440
# 00583 - peak code : 2828
# 00584 - peak code : 2824
# 00585 - peak code : 1799
# 00586 - peak code : 2770
# 00587 - peak code : 1764
# 00588 - peak code : 952
# 00589 - peak code : 4280
# 00590 - peak code : 1167
# 00591 - peak code : 840
# 00592 - peak code : 412
# 00593 - peak code : 2546
# 00594 - peak code : 962
# 00595 - peak code : 275
# 00596 - peak code : 912
# 00597 - peak code : 3339
# 00598 - peak code : 2316
# 00599 - peak code : 3966
# 00600 - peak code : 2709
# 00601 - peak code : 2417
# 00602 - peak code : 2253
# 00603 - peak code : 2244
# 00604 - peak code : 2725
# 00605 - peak code : 53
# 00606 - peak code : 1860
# 00607 - peak code : 18
# 00608 - peak code : 4309
# 00609 - peak code : 1795
# 00610 - peak code : 2712
# 00611 - peak code : 2440
# 00612 - peak code : 4327
# 00613 - peak code : 26
# 00614 - peak code : 4228
# 00615 - peak code : 1919
# 00616 - peak code : 4322
# 00617 - peak code : 982
# 00618 - peak code : 2071
# 00619 - peak code : 2072
# 00620 - peak code : 1891
# 00621 - peak code : 2802
# 00622 - peak code : 4301
# 00623 - peak code : 2282
# 00624 - peak code : 4326
# 00625 - peak code : 3138
# 00626 - peak code : 4289
# 00627 - peak code : 2284
# 00628 - peak code : 1431
# 00629 - peak code : 1793
# 00630 - peak code : 291
# 00631 - peak code : 3216
# 00632 - peak code : 4287
# 00633 - peak code : 3015
# 00634 - peak code : 1883
# 00635 - peak code : 2283
# 00636 - peak code : 2557
# 00637 - peak code : 4313
# 00638 - peak code : 4025
# 00639 - peak code : 2036
# 00640 - peak code : 2280
# 00641 - peak code : 4026
# 00642 - peak code : 4003
# 00643 - peak code : 4023
# 00644 - peak code : 1726
# 00645 - peak code : 3730
# 00646 - peak code : 4299
# 00647 - peak code : 2246
# 00648 - peak code : 2245
# 00649 - peak code : 4393
# 00650 - peak code : 2034
# 00651 - peak code : 4021
# 00652 - peak code : 2251
# 00653 - peak code : 1964
# 00654 - peak code : 2180
# 00655 - peak code : 3318
# 00656 - peak code : 70
# 00657 - peak code : 2267
# 00658 - peak code : 1661
# 00659 - peak code : 4300
# 00660 - peak code : 4031
# 00661 - peak code : 2035
# 00662 - peak code : 2963
# 00663 - peak code : 4398
# 00664 - peak code : 1149
# 00665 - peak code : 2256
# 00666 - peak code : 2249
# 00667 - peak code : 3715
# 00668 - peak code : 1903
# 00669 - peak code : 2259
# 00670 - peak code : 1074
# 00671 - peak code : 2255
# 00672 - peak code : 2333
# 00673 - peak code : 2476
# 00674 - peak code : 4306
# 00675 - peak code : 2247
# 00676 - peak code : 4024
# 00677 - peak code : 4030
# 00678 - peak code : 2252
# 00679 - peak code : 4308
# 00680 - peak code : 2263
# 00681 - peak code : 2646
# 00682 - peak code : 145
# 00683 - peak code : 717
# 00684 - peak code : 4048
# 00685 - peak code : 2260
# 00686 - peak code : 3311
# 00687 - peak code : 2163
# 00688 - peak code : 4298
# 00689 - peak code : 1085
# 00690 - peak code : 3836
# 00691 - peak code : 1028
# 00692 - peak code : 2862
# 00693 - peak code : 4315
# 00694 - peak code : 4558
# 00695 - peak code : 1798
# 00696 - peak code : 4330
# 00697 - peak code : 2743
# 00698 - peak code : 3316
# 00699 - peak code : 2243
# 00700 - peak code : 312
# 00701 - peak code : 1959
# 00702 - peak code : 2794
# 00703 - peak code : 203
# 00704 - peak code : 2278
# 00705 - peak code : 4227
# 00706 - peak code : 3462
# 00707 - peak code : 2099
# 00708 - peak code : 1459
# 00709 - peak code : 333
# 00710 - peak code : 4699
# 00711 - peak code : 3193
# 00712 - peak code : 2227
# 00713 - peak code : 4402
# 00714 - peak code : 4310
# 00715 - peak code : 2012
# 00716 - peak code : 2886
# 00717 - peak code : 219
# 00718 - peak code : 4394
# 00719 - peak code : 2250
# 00720 - peak code : 4307
# 00721 - peak code : 4312
# 00722 - peak code : 4403
# 00723 - peak code : 2528
# 00724 - peak code : 3855
# 00725 - peak code : 2363
# 00726 - peak code : 1377
# 00727 - peak code : 247
# 00728 - peak code : 2281
# 00729 - peak code : 4397
# 00730 - peak code : 4328
# 00731 - peak code : 1404
# 00732 - peak code : 4401
# 00733 - peak code : 4288
# 00734 - peak code : 4304
# 00735 - peak code : 1870
# 00736 - peak code : 321
# 00737 - peak code : 2416
# 00738 - peak code : 884
# 00739 - peak code : 3313
# 00740 - peak code : 4323
# 00741 - peak code : 1794
# 00742 - peak code : 450
# 00743 - peak code : 2889
# 00744 - peak code : 2248
# 00745 - peak code : 2533
# 00746 - peak code : 4311
# 00747 - peak code : 1728
# 00748 - peak code : 1796
# 00749 - peak code : 992
# 00750 - peak code : 4314
# 00751 - peak code : 2799
# 00752 - peak code : 2279
# 00753 - peak code : 4305
# 00754 - peak code : 2521
# 00755 - peak code : 2056
# 00756 - peak code : 1910
# 00757 - peak code : 3097
# 00758 - peak code : 3544
# 00759 - peak code : 1716
# 00760 - peak code : 757
# 00761 - peak code : 2334
# 00762 - peak code : 4114
# 00763 - peak code : 4090
# 00764 - peak code : 1972
# 00765 - peak code : 2687
# 00766 - peak code : 822
# 00767 - peak code : 3989
# 00768 - peak code : 1135
# 00769 - peak code : 3447
# 00770 - peak code : 980
# 00771 - peak code : 2578
# 00772 - peak code : 293
# 00773 - peak code : 733
# 00774 - peak code : 1672
# 00775 - peak code : 4420
# 00776 - peak code : 4467
# 00777 - peak code : 629
# 00778 - peak code : 2602
# 00779 - peak code : 875
# 00780 - peak code : 3887
# 00781 - peak code : 3452
# 00782 - peak code : 1254
# 00783 - peak code : 1593
# 00784 - peak code : 1255
# 00785 - peak code : 1596
# 00786 - peak code : 5
# 00787 - peak code : 4
# 00788 - peak code : 2109
# 00789 - peak code : 3365
# 00790 - peak code : 7
# 00791 - peak code : 330
# 00792 - peak code : 1202
# 00793 - peak code : 1252
# 00794 - peak code : 2443
# 00795 - peak code : 2339
# 00796 - peak code : 146
# 00797 - peak code : 1083
# 00798 - peak code : 4352
# 00799 - peak code : 4205
# 00800 - peak code : 2893
# 00801 - peak code : 600
# 00802 - peak code : 490
# 00803 - peak code : 3863
# 00804 - peak code : 280
# 00805 - peak code : 1769
# 00806 - peak code : 424
# 00807 - peak code : 3112
# 00808 - peak code : 713
# 00809 - peak code : 1521
# 00810 - peak code : 669
# 00811 - peak code : 1075
# 00812 - peak code : 2475
# 00813 - peak code : 15
# 00814 - peak code : 1420
# 00815 - peak code : 1416
# 00816 - peak code : 1122
# 00817 - peak code : 1571
# 00818 - peak code : 17
# 00819 - peak code : 1663
# 00820 - peak code : 2574
# 00821 - peak code : 2158
# 00822 - peak code : 3852
# 00823 - peak code : 1112
# 00824 - peak code : 3582
# 00825 - peak code : 3583
# 00826 - peak code : 1141
# 00827 - peak code : 2536
# 00828 - peak code : 4223
# 00829 - peak code : 2500
# 00830 - peak code : 2448
# 00831 - peak code : 3656
# 00832 - peak code : 3984
# 00833 - peak code : 2742
# 00834 - peak code : 2126
# 00835 - peak code : 4073
# 00836 - peak code : 2409
# 00837 - peak code : 25
# 00838 - peak code : 933
# 00839 - peak code : 3440
# 00840 - peak code : 2880
# 00841 - peak code : 3990
# 00842 - peak code : 2702
# 00843 - peak code : 3671
# 00844 - peak code : 3669
# 00845 - peak code : 4232
# 00846 - peak code : 882
# 00847 - peak code : 4222
# 00848 - peak code : 4083
# 00849 - peak code : 4060
# 00850 - peak code : 4207
# 00851 - peak code : 3419
# 00852 - peak code : 1094
# 00853 - peak code : 2556
# 00854 - peak code : 3043
# 00855 - peak code : 2554
# 00856 - peak code : 2887
# 00857 - peak code : 3153
# 00858 - peak code : 3572
# 00859 - peak code : 3849
# 00860 - peak code : 2552
# 00861 - peak code : 3606
# 00862 - peak code : 745
# 00863 - peak code : 738
# 00864 - peak code : 2433
# 00865 - peak code : 492
# 00866 - peak code : 500
# 00867 - peak code : 1206
# 00868 - peak code : 29
# 00869 - peak code : 3099
# 00870 - peak code : 3899
# 00871 - peak code : 739
# 00872 - peak code : 2509
# 00873 - peak code : 2085
# 00874 - peak code : 3654
# 00875 - peak code : 1401
# 00876 - peak code : 4109
# 00877 - peak code : 30
# 00878 - peak code : 4698
# 00879 - peak code : 4220
# 00880 - peak code : 825
# 00881 - peak code : 2714
# 00882 - peak code : 475
# 00883 - peak code : 2150
# 00884 - peak code : 578
# 00885 - peak code : 2465
# 00886 - peak code : 501
# 00887 - peak code : 489
# 00888 - peak code : 1154
# 00889 - peak code : 459
# 00890 - peak code : 2754
# 00891 - peak code : 343
# 00892 - peak code : 2504
# 00893 - peak code : 2169
# 00894 - peak code : 1540
# 00895 - peak code : 1821
# 00896 - peak code : 2572
# 00897 - peak code : 436
# 00898 - peak code : 173
# 00899 - peak code : 1403
# 00900 - peak code : 779
# 00901 - peak code : 3539
# 00902 - peak code : 1175
# 00903 - peak code : 2903
# 00904 - peak code : 1957
# 00905 - peak code : 3652
# 00906 - peak code : 1666
# 00907 - peak code : 1334
# 00908 - peak code : 3997
# 00909 - peak code : 517
# 00910 - peak code : 973
# 00911 - peak code : 549
# 00912 - peak code : 3806
# 00913 - peak code : 441
# 00914 - peak code : 4183
# 00915 - peak code : 2908
# 00916 - peak code : 468
# 00917 - peak code : 4054
# 00918 - peak code : 3069
# 00919 - peak code : 2164
# 00920 - peak code : 1731
# 00921 - peak code : 3445
# 00922 - peak code : 1212
# 00923 - peak code : 572
# 00924 - peak code : 427
# 00925 - peak code : 1425
# 00926 - peak code : 1797
# 00927 - peak code : 3642
# 00928 - peak code : 1256
# 00929 - peak code : 2400
# 00930 - peak code : 786
# 00931 - peak code : 519
# 00932 - peak code : 1184
# 00933 - peak code : 746
# 00934 - peak code : 1702
# 00935 - peak code : 1208
# 00936 - peak code : 2314
# 00937 - peak code : 2856
# 00938 - peak code : 2558
# 00939 - peak code : 4100
# 00940 - peak code : 2968
# 00941 - peak code : 787
# 00942 - peak code : 4178
# 00943 - peak code : 1266
# 00944 - peak code : 1643
# 00945 - peak code : 1665
# 00946 - peak code : 3995
# 00947 - peak code : 1402
# 00948 - peak code : 1265
# 00949 - peak code : 1282
# 00950 - peak code : 3953
# 00951 - peak code : 2396
# 00952 - peak code : 1323
# 00953 - peak code : 3931
# 00954 - peak code : 39
# 00955 - peak code : 3148
# 00956 - peak code : 2272
# 00957 - peak code : 4569
# 00958 - peak code : 4069
# 00959 - peak code : 587
# 00960 - peak code : 2240
# 00961 - peak code : 2239
# 00962 - peak code : 4154
# 00963 - peak code : 3042
# 00964 - peak code : 1670
# 00965 - peak code : 2463
# 00966 - peak code : 1541
# 00967 - peak code : 477
# 00968 - peak code : 2124
# 00969 - peak code : 2042
# 00970 - peak code : 2110
# 00971 - peak code : 4022
# 00972 - peak code : 2143
# 00973 - peak code : 2576
# 00974 - peak code : 1469
# 00975 - peak code : 2878
# 00976 - peak code : 2444
# 00977 - peak code : 4084
# 00978 - peak code : 3334
# 00979 - peak code : 2895
# 00980 - peak code : 4070
# 00981 - peak code : 1588
# 00982 - peak code : 4080
# 00983 - peak code : 594
# 00984 - peak code : 2159
# 00985 - peak code : 4410
# 00986 - peak code : 4072
# 00987 - peak code : 45
# 00988 - peak code : 1946
# 00989 - peak code : 202
# 00990 - peak code : 2237
# 00991 - peak code : 4386
# 00992 - peak code : 2236
# 00993 - peak code : 2218
# 00994 - peak code : 1599
# 00995 - peak code : 4479
# 00996 - peak code : 2865
# 00997 - peak code : 4485
# 00998 - peak code : 4404
# 00999 - peak code : 4491
# 01000 - peak code : 499
# 01001 - peak code : 2900
# 01002 - peak code : 4049
# 01003 - peak code : 1945
# 01004 - peak code : 1104
# 01005 - peak code : 1423
# 01006 - peak code : 1678
# 01007 - peak code : 1030
# 01008 - peak code : 3970
# 01009 - peak code : 1738
# 01010 - peak code : 2599
# 01011 - peak code : 316
# 01012 - peak code : 1600
# 01013 - peak code : 4217
# 01014 - peak code : 487
# 01015 - peak code : 949
# 01016 - peak code : 1207
# 01017 - peak code : 1414
# 01018 - peak code : 1508
# 01019 - peak code : 1944
# 01020 - peak code : 2891
# 01021 - peak code : 3569
# 01022 - peak code : 1589
# 01023 - peak code : 4405
# 01024 - peak code : 54
# 01025 - peak code : 1444
# 01026 - peak code : 4051
# 01027 - peak code : 1146
# 01028 - peak code : 4350
# 01029 - peak code : 1209
# 01030 - peak code : 2643
# 01031 - peak code : 4105
# 01032 - peak code : 1375
# 01033 - peak code : 3615
# 01034 - peak code : 2077
# 01035 - peak code : 1231
# 01036 - peak code : 3421
# 01037 - peak code : 3942
# 01038 - peak code : 1204
# 01039 - peak code : 4052
# 01040 - peak code : 4164
# 01041 - peak code : 2388
# 01042 - peak code : 4201
# 01043 - peak code : 1792
# 01044 - peak code : 3888
# 01045 - peak code : 3441
# 01046 - peak code : 3915
# 01047 - peak code : 315
# 01048 - peak code : 2051
# 01049 - peak code : 1986
# 01050 - peak code : 2512
# 01051 - peak code : 1896
# 01052 - peak code : 4416
# 01053 - peak code : 4354
# 01054 - peak code : 1161
# 01055 - peak code : 823
# 01056 - peak code : 798
# 01057 - peak code : 2701
# 01058 - peak code : 4679
# 01059 - peak code : 1088
# 01060 - peak code : 1649
# 01061 - peak code : 4210
# 01062 - peak code : 3041
# 01063 - peak code : 806
# 01064 - peak code : 2049
# 01065 - peak code : 774
# 01066 - peak code : 66
# 01067 - peak code : 1067
# 01068 - peak code : 4515
# 01069 - peak code : 3818
# 01070 - peak code : 2772
# 01071 - peak code : 3562
# 01072 - peak code : 271
# 01073 - peak code : 4056
# 01074 - peak code : 3890
# 01075 - peak code : 1018
# 01076 - peak code : 937
# 01077 - peak code : 67
# 01078 - peak code : 1782
# 01079 - peak code : 1062
# 01080 - peak code : 3763
# 01081 - peak code : 4093
# 01082 - peak code : 968
# 01083 - peak code : 71
# 01084 - peak code : 3682
# 01085 - peak code : 3812
# 01086 - peak code : 3851
# 01087 - peak code : 2387
# 01088 - peak code : 1059
# 01089 - peak code : 3689
# 01090 - peak code : 999
# 01091 - peak code : 1951
# 01092 - peak code : 3717
# 01093 - peak code : 2419
# 01094 - peak code : 4318
# 01095 - peak code : 2761
# 01096 - peak code : 3464
# 01097 - peak code : 2369
# 01098 - peak code : 3778
# 01099 - peak code : 1292
# 01100 - peak code : 78
# 01101 - peak code : 1195
# 01102 - peak code : 3678
# 01103 - peak code : 2791
# 01104 - peak code : 2287
# 01105 - peak code : 3822
# 01106 - peak code : 535
# 01107 - peak code : 4500
# 01108 - peak code : 2128
# 01109 - peak code : 2912
# 01110 - peak code : 3657
# 01111 - peak code : 3571
# 01112 - peak code : 3765
# 01113 - peak code : 2569
# 01114 - peak code : 3756
# 01115 - peak code : 3850
# 01116 - peak code : 3819
# 01117 - peak code : 1577
# 01118 - peak code : 1091
# 01119 - peak code : 1417
# 01120 - peak code : 4578
# 01121 - peak code : 1455
# 01122 - peak code : 2187
# 01123 - peak code : 439
# 01124 - peak code : 4180
# 01125 - peak code : 2420
# 01126 - peak code : 2510
# 01127 - peak code : 619
# 01128 - peak code : 1115
# 01129 - peak code : 3218
# 01130 - peak code : 3693
# 01131 - peak code : 3901
# 01132 - peak code : 3250
# 01133 - peak code : 1690
# 01134 - peak code : 1827
# 01135 - peak code : 4197
# 01136 - peak code : 1490
# 01137 - peak code : 961
# 01138 - peak code : 3540
# 01139 - peak code : 478
# 01140 - peak code : 1627
# 01141 - peak code : 2562
# 01142 - peak code : 4536
# 01143 - peak code : 2664
# 01144 - peak code : 87
# 01145 - peak code : 2437
# 01146 - peak code : 3862
# 01147 - peak code : 555
# 01148 - peak code : 3801
# 01149 - peak code : 1142
# 01150 - peak code : 4208
# 01151 - peak code : 1523
# 01152 - peak code : 3894
# 01153 - peak code : 3696
# 01154 - peak code : 2774
# 01155 - peak code : 3537
# 01156 - peak code : 4353
# 01157 - peak code : 1432
# 01158 - peak code : 4406
# 01159 - peak code : 3773
# 01160 - peak code : 92
# 01161 - peak code : 550
# 01162 - peak code : 2352
# 01163 - peak code : 1399
# 01164 - peak code : 2866
# 01165 - peak code : 3087
# 01166 - peak code : 2344
# 01167 - peak code : 2111
# 01168 - peak code : 4547
# 01169 - peak code : 2958
# 01170 - peak code : 1825
# 01171 - peak code : 1243
# 01172 - peak code : 1527
# 01173 - peak code : 3932
# 01174 - peak code : 4441
# 01175 - peak code : 95
# 01176 - peak code : 646
# 01177 - peak code : 1020
# 01178 - peak code : 498
# 01179 - peak code : 457
# 01180 - peak code : 2136
# 01181 - peak code : 3758
# 01182 - peak code : 2345
# 01183 - peak code : 841
# 01184 - peak code : 4535
# 01185 - peak code : 1311
# 01186 - peak code : 4120
# 01187 - peak code : 1845
# 01188 - peak code : 3813
# 01189 - peak code : 3803
# 01190 - peak code : 3091
# 01191 - peak code : 1774
# 01192 - peak code : 3771
# 01193 - peak code : 3630
# 01194 - peak code : 2351
# 01195 - peak code : 96
# 01196 - peak code : 883
# 01197 - peak code : 2308
# 01198 - peak code : 3326
# 01199 - peak code : 598
# 01200 - peak code : 4063
# 01201 - peak code : 97
# 01202 - peak code : 282
# 01203 - peak code : 2731
# 01204 - peak code : 1688
# 01205 - peak code : 4032
# 01206 - peak code : 2482
# 01207 - peak code : 359
# 01208 - peak code : 3444
# 01209 - peak code : 472
# 01210 - peak code : 4009
# 01211 - peak code : 1039
# 01212 - peak code : 2286
# 01213 - peak code : 1124
# 01214 - peak code : 586
# 01215 - peak code : 1685
# 01216 - peak code : 4044
# 01217 - peak code : 4215
# 01218 - peak code : 900
# 01219 - peak code : 319
# 01220 - peak code : 4303
# 01221 - peak code : 4221
# 01222 - peak code : 406
# 01223 - peak code : 1966
# 01224 - peak code : 3754
# 01225 - peak code : 3660
# 01226 - peak code : 3661
# 01227 - peak code : 1730
# 01228 - peak code : 1587
# 01229 - peak code : 3448
# 01230 - peak code : 704
# 01231 - peak code : 726
# 01232 - peak code : 4609
# 01233 - peak code : 3450
# 01234 - peak code : 385
# 01235 - peak code : 660
# 01236 - peak code : 384
# 01237 - peak code : 4571
# 01238 - peak code : 1693
# 01239 - peak code : 509
# 01240 - peak code : 794
# 01241 - peak code : 3975
# 01242 - peak code : 3725
# 01243 - peak code : 101
# 01244 - peak code : 571
# 01245 - peak code : 102
# 01246 - peak code : 2904
# 01247 - peak code : 1520
# 01248 - peak code : 665
# 01249 - peak code : 4331
# 01250 - peak code : 1874
# 01251 - peak code : 302
# 01252 - peak code : 2370
# 01253 - peak code : 2503
# 01254 - peak code : 2577
# 01255 - peak code : 3593
# 01256 - peak code : 1772
# 01257 - peak code : 1188
# 01258 - peak code : 1846
# 01259 - peak code : 2139
# 01260 - peak code : 592
# 01261 - peak code : 1524
# 01262 - peak code : 4061
# 01263 - peak code : 3979
# 01264 - peak code : 4108
# 01265 - peak code : 1257
# 01266 - peak code : 3814
# 01267 - peak code : 3950
# 01268 - peak code : 4348
# 01269 - peak code : 4064
# 01270 - peak code : 3838
# 01271 - peak code : 107
# 01272 - peak code : 814
# 01273 - peak code : 554
# 01274 - peak code : 616
# 01275 - peak code : 4094
# 01276 - peak code : 2797
# 01277 - peak code : 2867
# 01278 - peak code : 721
# 01279 - peak code : 705
# 01280 - peak code : 3807
# 01281 - peak code : 3722
# 01282 - peak code : 2172
# 01283 - peak code : 3187
# 01284 - peak code : 3790
# 01285 - peak code : 1241
# 01286 - peak code : 3319
# 01287 - peak code : 3144
# 01288 - peak code : 1471
# 01289 - peak code : 3449
# 01290 - peak code : 1038
# 01291 - peak code : 648
# 01292 - peak code : 1223
# 01293 - peak code : 1133
# 01294 - peak code : 3776
# 01295 - peak code : 1410
# 01296 - peak code : 3558
# 01297 - peak code : 844
# 01298 - peak code : 3573
# 01299 - peak code : 351
# 01300 - peak code : 1534
# 01301 - peak code : 3534
# 01302 - peak code : 4074
# 01303 - peak code : 1239
# 01304 - peak code : 3585
# 01305 - peak code : 1409
# 01306 - peak code : 1395
# 01307 - peak code : 727
# 01308 - peak code : 3740
# 01309 - peak code : 2933
# 01310 - peak code : 2041
# 01311 - peak code : 1191
# 01312 - peak code : 2264
# 01313 - peak code : 469
# 01314 - peak code : 1464
# 01315 - peak code : 513
# 01316 - peak code : 3442
# 01317 - peak code : 647
# 01318 - peak code : 3723
# 01319 - peak code : 1617
# 01320 - peak code : 4427
# 01321 - peak code : 1121
# 01322 - peak code : 3561
# 01323 - peak code : 869
# 01324 - peak code : 1975
# 01325 - peak code : 3797
# 01326 - peak code : 1641
# 01327 - peak code : 4087
# 01328 - peak code : 3742
# 01329 - peak code : 3538
# 01330 - peak code : 939
# 01331 - peak code : 4498
# 01332 - peak code : 3993
# 01333 - peak code : 4212
# 01334 - peak code : 3960
# 01335 - peak code : 4366
# 01336 - peak code : 4351
# 01337 - peak code : 119
# 01338 - peak code : 1422
# 01339 - peak code : 3554
# 01340 - peak code : 1189
# 01341 - peak code : 2016
# 01342 - peak code : 3699
# 01343 - peak code : 508
# 01344 - peak code : 3719
# 01345 - peak code : 4408
# 01346 - peak code : 1438
# 01347 - peak code : 4575
# 01348 - peak code : 2997
# 01349 - peak code : 3988
# 01350 - peak code : 2193
# 01351 - peak code : 3998
# 01352 - peak code : 4145
# 01353 - peak code : 1695
# 01354 - peak code : 125
# 01355 - peak code : 2833
# 01356 - peak code : 589
# 01357 - peak code : 2894
# 01358 - peak code : 4190
# 01359 - peak code : 128
# 01360 - peak code : 607
# 01361 - peak code : 1324
# 01362 - peak code : 1233
# 01363 - peak code : 3792
# 01364 - peak code : 4694
# 01365 - peak code : 1859
# 01366 - peak code : 1656
# 01367 - peak code : 782
# 01368 - peak code : 4497
# 01369 - peak code : 1814
# 01370 - peak code : 1301
# 01371 - peak code : 3759
# 01372 - peak code : 3755
# 01373 - peak code : 593
# 01374 - peak code : 511
# 01375 - peak code : 3744
# 01376 - peak code : 3994
# 01377 - peak code : 2876
# 01378 - peak code : 576
# 01379 - peak code : 134
# 01380 - peak code : 418
# 01381 - peak code : 922
# 01382 - peak code : 1306
# 01383 - peak code : 2175
# 01384 - peak code : 1519
# 01385 - peak code : 2406
# 01386 - peak code : 4251
# 01387 - peak code : 3597
# 01388 - peak code : 3662
# 01389 - peak code : 3595
# 01390 - peak code : 386
# 01391 - peak code : 1655
# 01392 - peak code : 3908
# 01393 - peak code : 4442
# 01394 - peak code : 3772
# 01395 - peak code : 1190
# 01396 - peak code : 2086
# 01397 - peak code : 2219
# 01398 - peak code : 2882
# 01399 - peak code : 1925
# 01400 - peak code : 1978
# 01401 - peak code : 1193
# 01402 - peak code : 1826
# 01403 - peak code : 3884
# 01404 - peak code : 1513
# 01405 - peak code : 575
# 01406 - peak code : 3992
# 01407 - peak code : 2274
# 01408 - peak code : 1017
# 01409 - peak code : 1851
# 01410 - peak code : 532
# 01411 - peak code : 179
# 01412 - peak code : 3570
# 01413 - peak code : 651
# 01414 - peak code : 760
# 01415 - peak code : 1016
# 01416 - peak code : 2027
# 01417 - peak code : 503
# 01418 - peak code : 3065
# 01419 - peak code : 2349
# 01420 - peak code : 3335
# 01421 - peak code : 3507
# 01422 - peak code : 1628
# 01423 - peak code : 1625
# 01424 - peak code : 2059
# 01425 - peak code : 3409
# 01426 - peak code : 2907
# 01427 - peak code : 2705
# 01428 - peak code : 2898
# 01429 - peak code : 4140
# 01430 - peak code : 123
# 01431 - peak code : 295
# 01432 - peak code : 3005
# 01433 - peak code : 2153
# 01434 - peak code : 4144
# 01435 - peak code : 286
# 01436 - peak code : 4209
# 01437 - peak code : 357
# 01438 - peak code : 1382
# 01439 - peak code : 2332
# 01440 - peak code : 2346
# 01441 - peak code : 3802
# 01442 - peak code : 526
# 01443 - peak code : 4570
# 01444 - peak code : 1943
# 01445 - peak code : 3906
# 01446 - peak code : 3356
# 01447 - peak code : 3451
# 01448 - peak code : 4065
# 01449 - peak code : 1144
# 01450 - peak code : 4142
# 01451 - peak code : 1152
# 01452 - peak code : 4433
# 01453 - peak code : 1646
# 01454 - peak code : 1673
# 01455 - peak code : 4486
# 01456 - peak code : 588
# 01457 - peak code : 3746
# 01458 - peak code : 352
# 01459 - peak code : 4411
# 01460 - peak code : 3454
# 01461 - peak code : 2800
# 01462 - peak code : 2515
# 01463 - peak code : 856
# 01464 - peak code : 2343
# 01465 - peak code : 491
# 01466 - peak code : 3907
# 01467 - peak code : 1544
# 01468 - peak code : 2565
# 01469 - peak code : 590
# 01470 - peak code : 678
# 01471 - peak code : 1436
# 01472 - peak code : 2474
# 01473 - peak code : 1510
# 01474 - peak code : 965
# 01475 - peak code : 2130
# 01476 - peak code : 534
# 01477 - peak code : 4218
# 01478 - peak code : 691
# 01479 - peak code : 1502
# 01480 - peak code : 3735
# 01481 - peak code : 2551
# 01482 - peak code : 4203
# 01483 - peak code : 2047
# 01484 - peak code : 2275
# 01485 - peak code : 1271
# 01486 - peak code : 182
# 01487 - peak code : 3553
# 01488 - peak code : 3598
# 01489 - peak code : 2179
# 01490 - peak code : 2573
# 01491 - peak code : 2550
# 01492 - peak code : 1611
# 01493 - peak code : 4409
# 01494 - peak code : 2881
# 01495 - peak code : 4444
# 01496 - peak code : 2501
# 01497 - peak code : 4177
# 01498 - peak code : 3933
# 01499 - peak code : 3199
# 01500 - peak code : 4085
# 01501 - peak code : 165
# 01502 - peak code : 3026
# 01503 - peak code : 4608
# 01504 - peak code : 1089
# 01505 - peak code : 896
# 01506 - peak code : 2129
# 01507 - peak code : 4103
# 01508 - peak code : 866
# 01509 - peak code : 2796
# 01510 - peak code : 2342
# 01511 - peak code : 2338
# 01512 - peak code : 1136
# 01513 - peak code : 518
# 01514 - peak code : 807
# 01515 - peak code : 3871
# 01516 - peak code : 1767
# 01517 - peak code : 4099
# 01518 - peak code : 1446
# 01519 - peak code : 3599
# 01520 - peak code : 3721
# 01521 - peak code : 2329
# 01522 - peak code : 3613
# 01523 - peak code : 3927
# 01524 - peak code : 2424
# 01525 - peak code : 3926
# 01526 - peak code : 2464
# 01527 - peak code : 2317
# 01528 - peak code : 4560
# 01529 - peak code : 929
# 01530 - peak code : 3581
# 01531 - peak code : 1558
# 01532 - peak code : 4369
# 01533 - peak code : 184
# 01534 - peak code : 288
# 01535 - peak code : 676
# 01536 - peak code : 3636
# 01537 - peak code : 1618
# 01538 - peak code : 4627
# 01539 - peak code : 375
# 01540 - peak code : 4395
# 01541 - peak code : 3889
# 01542 - peak code : 299
# 01543 - peak code : 4143
# 01544 - peak code : 1061
# 01545 - peak code : 4443
# 01546 - peak code : 4377
# 01547 - peak code : 2506
# 01548 - peak code : 553
# 01549 - peak code : 170
# 01550 - peak code : 1562
# 01551 - peak code : 2750
# 01552 - peak code : 1072
# 01553 - peak code : 496
# 01554 - peak code : 3936
# 01555 - peak code : 902
# 01556 - peak code : 531
# 01557 - peak code : 1246
# 01558 - peak code : 1551
# 01559 - peak code : 1253
# 01560 - peak code : 481
# 01561 - peak code : 3036
# 01562 - peak code : 599
# 01563 - peak code : 953
# 01564 - peak code : 4481
# 01565 - peak code : 3724
# 01566 - peak code : 1435
# 01567 - peak code : 1491
# 01568 - peak code : 2777
# 01569 - peak code : 1950
# 01570 - peak code : 4480
# 01571 - peak code : 2341
# 01572 - peak code : 2197
# 01573 - peak code : 1980
# 01574 - peak code : 4574
# 01575 - peak code : 65
# 01576 - peak code : 1344
# 01577 - peak code : 354
# 01578 - peak code : 1659
# 01579 - peak code : 1660
# 01580 - peak code : 4121
# 01581 - peak code : 4478
# 01582 - peak code : 2119
# 01583 - peak code : 4349
# 01584 - peak code : 4407
# 01585 - peak code : 2404
# 01586 - peak code : 391
# 01587 - peak code : 1607
# 01588 - peak code : 2184
# 01589 - peak code : 4400
# 01590 - peak code : 1484
# 01591 - peak code : 4573
# 01592 - peak code : 4123
# 01593 - peak code : 4385
# 01594 - peak code : 4490
# 01595 - peak code : 488
# 01596 - peak code : 1753
# 01597 - peak code : 207
# 01598 - peak code : 1648
# 01599 - peak code : 1008
# 01600 - peak code : 4134
# 01601 - peak code : 4680
# 01602 - peak code : 1302
# 01603 - peak code : 981
# 01604 - peak code : 4482
# 01605 - peak code : 434
# 01606 - peak code : 262
# 01607 - peak code : 990
# 01608 - peak code : 1433
# 01609 - peak code : 3603
# 01610 - peak code : 2704
# 01611 - peak code : 1487
# 01612 - peak code : 2289
# 01613 - peak code : 4199
# 01614 - peak code : 3643
# 01615 - peak code : 4075
# 01616 - peak code : 3604
# 01617 - peak code : 2819
# 01618 - peak code : 2371
# 01619 - peak code : 1236
# 01620 - peak code : 680
# 01621 - peak code : 322
# 01622 - peak code : 3541
# 01623 - peak code : 455
# 01624 - peak code : 1698
# 01625 - peak code : 4319
# 01626 - peak code : 2018
# 01627 - peak code : 2426
# 01628 - peak code : 1057
# 01629 - peak code : 1616
# 01630 - peak code : 3600
# 01631 - peak code : 402
# 01632 - peak code : 1186
# 01633 - peak code : 3027
# 01634 - peak code : 306
# 01635 - peak code : 1916
# 01636 - peak code : 2547
# 01637 - peak code : 3911
# 01638 - peak code : 1639
# 01639 - peak code : 1064
# 01640 - peak code : 1839
# 01641 - peak code : 2767
# 01642 - peak code : 4091
# 01643 - peak code : 703
# 01644 - peak code : 791
# 01645 - peak code : 2199
# 01646 - peak code : 2358
# 01647 - peak code : 4213
# 01648 - peak code : 4554
# 01649 - peak code : 1668
# 01650 - peak code : 601
# 01651 - peak code : 140
# 01652 - peak code : 4464
# 01653 - peak code : 2590
# 01654 - peak code : 597
# 01655 - peak code : 2897
# 01656 - peak code : 1776
# 01657 - peak code : 2324
# 01658 - peak code : 3192
# 01659 - peak code : 1962
# 01660 - peak code : 3691
# 01661 - peak code : 323
# 01662 - peak code : 2517
# 01663 - peak code : 199
# 01664 - peak code : 2571
# 01665 - peak code : 1071
# 01666 - peak code : 955
# 01667 - peak code : 1692
# 01668 - peak code : 1488
# 01669 - peak code : 2781
# 01670 - peak code : 4077
# 01671 - peak code : 4250
# 01672 - peak code : 790
# 01673 - peak code : 3827
# 01674 - peak code : 2932
# 01675 - peak code : 4043
# 01676 - peak code : 1872
# 01677 - peak code : 3895
# 01678 - peak code : 1779
# 01679 - peak code : 2399
# 01680 - peak code : 2347
# 01681 - peak code : 2439
# 01682 - peak code : 2885
# 01683 - peak code : 3565
# 01684 - peak code : 4079
# 01685 - peak code : 1609
# 01686 - peak code : 1086
# 01687 - peak code : 1877
# 01688 - peak code : 2879
# 01689 - peak code : 1244
# 01690 - peak code : 206
# 01691 - peak code : 690
# 01692 - peak code : 456
# 01693 - peak code : 4153
# 01694 - peak code : 1987
# 01695 - peak code : 4076
# 01696 - peak code : 1989
# 01697 - peak code : 671
# 01698 - peak code : 3580
# 01699 - peak code : 4198
# 01700 - peak code : 4176
# 01701 - peak code : 4172
# 01702 - peak code : 1955
# 01703 - peak code : 3861
# 01704 - peak code : 1379
# 01705 - peak code : 4160
# 01706 - peak code : 3247
# 01707 - peak code : 1529
# 01708 - peak code : 1466
# 01709 - peak code : 3515
# 01710 - peak code : 1866
# 01711 - peak code : 4542
# 01712 - peak code : 462
# 01713 - peak code : 1623
# 01714 - peak code : 712
# 01715 - peak code : 2427
# 01716 - peak code : 1187
# 01717 - peak code : 1802
# 01718 - peak code : 3839
# 01719 - peak code : 2539
# 01720 - peak code : 4166
# 01721 - peak code : 1117
# 01722 - peak code : 3579
# 01723 - peak code : 318
# 01724 - peak code : 4346
# 01725 - peak code : 1267
# 01726 - peak code : 1752
# 01727 - peak code : 1586
# 01728 - peak code : 1594
# 01729 - peak code : 3964
# 01730 - peak code : 4447
# 01731 - peak code : 1026
# 01732 - peak code : 2348
# 01733 - peak code : 1201
# 01734 - peak code : 3707
# 01735 - peak code : 2173
# 01736 - peak code : 3631
# 01737 - peak code : 1768
# 01738 - peak code : 2407
# 01739 - peak code : 2254
# 01740 - peak code : 1801
# 01741 - peak code : 3879
# 01742 - peak code : 1636
# 01743 - peak code : 3178
# 01744 - peak code : 2389
# 01745 - peak code : 1176
# 01746 - peak code : 2154
# 01747 - peak code : 4568
# 01748 - peak code : 971
# 01749 - peak code : 2675
# 01750 - peak code : 2291
# 01751 - peak code : 1941
# 01752 - peak code : 1525
# 01753 - peak code : 1536
# 01754 - peak code : 1177
# 01755 - peak code : 156
# 01756 - peak code : 793
# 01757 - peak code : 4008
# 01758 - peak code : 3891
# 01759 - peak code : 1694
# 01760 - peak code : 163
# 01761 - peak code : 2271
# 01762 - peak code : 4216
# 01763 - peak code : 4600
# 01764 - peak code : 1090
# 01765 - peak code : 2685
# 01766 - peak code : 880
# 01767 - peak code : 2269
# 01768 - peak code : 1181
# 01769 - peak code : 4157
# 01770 - peak code : 1900
# 01771 - peak code : 4173
# 01772 - peak code : 1576
# 01773 - peak code : 208
# 01774 - peak code : 799
# 01775 - peak code : 4214
# 01776 - peak code : 1447
# 01777 - peak code : 683
# 01778 - peak code : 2114
# 01779 - peak code : 1424
# 01780 - peak code : 1415
# 01781 - peak code : 2555
# 01782 - peak code : 1580
# 01783 - peak code : 3114
# 01784 - peak code : 697
# 01785 - peak code : 653
# 01786 - peak code : 1111
# 01787 - peak code : 620
# 01788 - peak code : 1264
# 01789 - peak code : 4489
# 01790 - peak code : 358
# 01791 - peak code : 2522
# 01792 - peak code : 4249
# 01793 - peak code : 367
# 01794 - peak code : 2413
# 01795 - peak code : 4029
# 01796 - peak code : 4112
# 01797 - peak code : 1568
# 01798 - peak code : 4106
# 01799 - peak code : 1970
# 01800 - peak code : 1626
# 01801 - peak code : 765
# 01802 - peak code : 2896
# 01803 - peak code : 1612
# 01804 - peak code : 2025
# 01805 - peak code : 1686
# 01806 - peak code : 3987
# 01807 - peak code : 3694
# 01808 - peak code : 3673
# 01809 - peak code : 4125
# 01810 - peak code : 1418
# 01811 - peak code : 4566
# 01812 - peak code : 4463
# 01813 - peak code : 3096
# 01814 - peak code : 4567
# 01815 - peak code : 1880
# 01816 - peak code : 1478
# 01817 - peak code : 1103
# 01818 - peak code : 3821
# 01819 - peak code : 1875
# 01820 - peak code : 689
# 01821 - peak code : 4670
# 01822 - peak code : 4184
# 01823 - peak code : 4347
# 01824 - peak code : 505
# 01825 - peak code : 2127
# 01826 - peak code : 4122
# 01827 - peak code : 2121
# 01828 - peak code : 4202
# 01829 - peak code : 1689
# 01830 - peak code : 211
# 01831 - peak code : 1754
# 01832 - peak code : 1984
# 01833 - peak code : 3991
# 01834 - peak code : 3996
# 01835 - peak code : 4104
# 01836 - peak code : 710
# 01837 - peak code : 4493
# 01838 - peak code : 3591
# 01839 - peak code : 3611
# 01840 - peak code : 3609
# 01841 - peak code : 2934
# 01842 - peak code : 1164
# 01843 - peak code : 4101
# 01844 - peak code : 1362
# 01845 - peak code : 3453
# 01846 - peak code : 4495
# 01847 - peak code : 1185
# 01848 - peak code : 4365
# 01849 - peak code : 4426
# 01850 - peak code : 4361
# 01851 - peak code : 4362
# 01852 - peak code : 4329
# 01853 - peak code : 4292
# 01854 - peak code : 4325
# 01855 - peak code : 2238
# 01856 - peak code : 1450
# 01857 - peak code : 4389
# 01858 - peak code : 422
# 01859 - peak code : 4019
# 01860 - peak code : 4345
# 01861 - peak code : 4136
# 01862 - peak code : 1467
# 01863 - peak code : 542
# ...
# 03574 - peak code : 61
# 03575 - peak code : 136
# 03576 - peak code : 3214
# 03577 - peak code : 326
# 03578 - peak code : 2960
# 03579 - peak code : 3052
# 03580 - peak code : 416
# 03581 - peak code : 923
# 03582 - peak code : 2979
# 03583 - peak code : 482
# 03584 - peak code : 238
# 03585 - peak code : 3478
# 03586 - peak code : 3308
# 03587 - peak code : 816
# 03588 - peak code : 304
# 03589 - peak code : 2996
# 03590 - peak code : 1251
# 03591 - peak code : 365
# 03592 - peak code : 297
# 03593 - peak code : 1791
# 03594 - peak code : 307
# 03595 - peak code : 3629
# 03596 - peak code : 239
# 03597 - peak code : 240
# 03598 - peak code : 4128
# 03599 - peak code : 1813
# 03600 - peak code : 895
# 03601 - peak code : 3272
# 03602 - peak code : 3168
# 03603 - peak code : 3588
# 03604 - peak code : 2033
# 03605 - peak code : 3527
# 03606 - peak code : 4456
# 03607 - peak code : 741
# 03608 - peak code : 2863
# 03609 - peak code : 831
# 03610 - peak code : 1898
# 03611 - peak code : 1281
# 03612 - peak code : 4317
# 03613 - peak code : 4638
# 03614 - peak code : 2082
# 03615 - peak code : 3705
# 03616 - peak code : 2106
# 03617 - peak code : 3298
# 03618 - peak code : 3437
# 03619 - peak code : 2229
# 03620 - peak code : 1106
# 03621 - peak code : 506
# 03622 - peak code : 2053
# 03623 - peak code : 4477
# 03624 - peak code : 4468
# 03625 - peak code : 3912
# 03626 - peak code : 614
# 03627 - peak code : 4611
# 03628 - peak code : 891
# 03629 - peak code : 3008
# 03630 - peak code : 4473
# 03631 - peak code : 2379
# 03632 - peak code : 3085
# 03633 - peak code : 1584
# 03634 - peak code : 3267
# 03635 - peak code : 4041
# 03636 - peak code : 1001
# 03637 - peak code : 1709
# 03638 - peak code : 2367
# 03639 - peak code : 2312
# 03640 - peak code : 3426
# 03641 - peak code : 563
# 03642 - peak code : 972
# 03643 - peak code : 2310
# 03644 - peak code : 2313
# 03645 - peak code : 4690
# 03646 - peak code : 447
# 03647 - peak code : 2368
# 03648 - peak code : 4371
# 03649 - peak code : 2037
# 03650 - peak code : 3648
# 03651 - peak code : 3605
# 03652 - peak code : 569
# 03653 - peak code : 3602
# 03654 - peak code : 1259
# 03655 - peak code : 3301
# 03656 - peak code : 3644
# 03657 - peak code : 494
# 03658 - peak code : 4193
# 03659 - peak code : 4504
# 03660 - peak code : 466
# 03661 - peak code : 4126
# 03662 - peak code : 1604
# 03663 - peak code : 3514
# 03664 - peak code : 3910
# 03665 - peak code : 4494
# 03666 - peak code : 2787
# 03667 - peak code : 3840
# 03668 - peak code : 938
# 03669 - peak code : 4662
# 03670 - peak code : 2266
# 03671 - peak code : 1784
# 03672 - peak code : 2638
# 03673 - peak code : 1882
# 03674 - peak code : 248
# 03675 - peak code : 2067
# 03676 - peak code : 743
# 03677 - peak code : 3876
# 03678 - peak code : 1963
# 03679 - peak code : 1166
# 03680 - peak code : 249
# 03681 - peak code : 3928
# 03682 - peak code : 3222
# 03683 - peak code : 4382
# 03684 - peak code : 3060
# 03685 - peak code : 1573
# 03686 - peak code : 4665
# 03687 - peak code : 4689
# 03688 - peak code : 865
# 03689 - peak code : 4649
# 03690 - peak code : 4630
# 03691 - peak code : 3474
# 03692 - peak code : 3264
# 03693 - peak code : 3084
# 03694 - peak code : 2195
# 03695 - peak code : 349
# 03696 - peak code : 515
# 03697 - peak code : 4503
# 03698 - peak code : 944
# 03699 - peak code : 888
# 03700 - peak code : 4648
# 03701 - peak code : 1381
# 03702 - peak code : 1657
# 03703 - peak code : 1887
# 03704 - peak code : 3126
# 03705 - peak code : 3123
# 03706 - peak code : 3212
# 03707 - peak code : 4293
# 03708 - peak code : 538
# 03709 - peak code : 1775
# 03710 - peak code : 1512
# 03711 - peak code : 3374
# 03712 - peak code : 911
# 03713 - peak code : 582
# 03714 - peak code : 1783
# 03715 - peak code : 4643
# 03716 - peak code : 250
# 03717 - peak code : 4563
# 03718 - peak code : 4625
# 03719 - peak code : 3711
# 03720 - peak code : 251
# 03721 - peak code : 3208
# 03722 - peak code : 4316
# 03723 - peak code : 68
# 03724 - peak code : 442
# 03725 - peak code : 1297
# 03726 - peak code : 1920
# 03727 - peak code : 393
# 03728 - peak code : 4687
# 03729 - peak code : 514
# 03730 - peak code : 1493
# 03731 - peak code : 2957
# 03732 - peak code : 1279
# 03733 - peak code : 3066
# 03734 - peak code : 3885
# 03735 - peak code : 3004
# 03736 - peak code : 1808
# 03737 - peak code : 2786
# 03738 - peak code : 3059
# 03739 - peak code : 305
# 03740 - peak code : 1340
# 03741 - peak code : 559
# 03742 - peak code : 3127
# 03743 - peak code : 3061
# 03744 - peak code : 2938
# 03745 - peak code : 3202
# 03746 - peak code : 3309
# 03747 - peak code : 1277
# 03748 - peak code : 2076
# 03749 - peak code : 1516
# 03750 - peak code : 1226
# 03751 - peak code : 474
# 03752 - peak code : 1742
# 03753 - peak code : 3276
# 03754 - peak code : 4661
# 03755 - peak code : 3370
# 03756 - peak code : 2078
# 03757 - peak code : 3358
# 03758 - peak code : 4688
# 03759 - peak code : 826
# 03760 - peak code : 1157
# 03761 - peak code : 2953
# 03762 - peak code : 2436
# 03763 - peak code : 3102
# 03764 - peak code : 735
# 03765 - peak code : 950
# 03766 - peak code : 1610
# 03767 - peak code : 303
# 03768 - peak code : 3012
# 03769 - peak code : 3258
# 03770 - peak code : 636
# 03771 - peak code : 3467
# 03772 - peak code : 4000
# 03773 - peak code : 3734
# 03774 - peak code : 3274
# 03775 - peak code : 4622
# 03776 - peak code : 4460
# 03777 - peak code : 1722
# 03778 - peak code : 3166
# 03779 - peak code : 1221
# 03780 - peak code : 3869
# 03781 - peak code : 753
# 03782 - peak code : 1603
# 03783 - peak code : 3294
# 03784 - peak code : 3140
# 03785 - peak code : 2068
# 03786 - peak code : 1727
# 03787 - peak code : 4418
# 03788 - peak code : 3883
# 03789 - peak code : 355
# 03790 - peak code : 4419
# 03791 - peak code : 3867
# 03792 - peak code : 3873
# 03793 - peak code : 2355
# 03794 - peak code : 4335
# 03795 - peak code : 3878
# 03796 - peak code : 3857
# 03797 - peak code : 3865
# 03798 - peak code : 4657
# 03799 - peak code : 1718
# 03800 - peak code : 263
# 03801 - peak code : 1470
# 03802 - peak code : 3304
# 03803 - peak code : 4623
# 03804 - peak code : 419
# 03805 - peak code : 1200
# 03806 - peak code : 3262
# 03807 - peak code : 1809
# 03808 - peak code : 3548
# 03809 - peak code : 3139
# 03810 - peak code : 2211
# 03811 - peak code : 264
# 03812 - peak code : 583
# 03813 - peak code : 2096
# 03814 - peak code : 3128
# 03815 - peak code : 4540
# 03816 - peak code : 1762
# 03817 - peak code : 1538
# 03818 - peak code : 2258
# 03819 - peak code : 2910
# 03820 - peak code : 2188
# 03821 - peak code : 3687
# 03822 - peak code : 2186
# 03823 - peak code : 2330
# 03824 - peak code : 4539
# 03825 - peak code : 1988
# 03826 - peak code : 4297
# 03827 - peak code : 1548
# 03828 - peak code : 452
# 03829 - peak code : 2920
# 03830 - peak code : 267
# 03831 - peak code : 268
# 03832 - peak code : 1755
# 03833 - peak code : 702
# 03834 - peak code : 701
# 03835 - peak code : 2964
# 03836 - peak code : 1337
# 03837 - peak code : 3431
# 03838 - peak code : 3456
# 03839 - peak code : 3101
# 03840 - peak code : 380
# 03841 - peak code : 921
# 03842 - peak code : 1322
# 03843 - peak code : 3843
# 03844 - peak code : 3167
# 03845 - peak code : 2028
# 03846 - peak code : 3205
# 03847 - peak code : 426
# 03848 - peak code : 2327
# 03849 - peak code : 269
# 03850 - peak code : 353
# 03851 - peak code : 2092
# 03852 - peak code : 1479
# 03853 - peak code : 2233
# 03854 - peak code : 4637
# 03855 - peak code : 272
# 03856 - peak code : 363
# 03857 - peak code : 350
# 03858 - peak code : 3342
# 03859 - peak code : 1051
# 03860 - peak code : 3014
# 03861 - peak code : 2776
# 03862 - peak code : 564
# 03863 - peak code : 3175
# 03864 - peak code : 2354
# 03865 - peak code : 4597
# 03866 - peak code : 2328
# 03867 - peak code : 3491
# 03868 - peak code : 3432
# 03869 - peak code : 4189
# 03870 - peak code : 3701
# 03871 - peak code : 4534
# 03872 - peak code : 4667
# 03873 - peak code : 273
# 03874 - peak code : 4036
# 03875 - peak code : 800
# 03876 - peak code : 2422
# 03877 - peak code : 3287
# 03878 - peak code : 1843
# 03879 - peak code : 602
# 03880 - peak code : 2090
# 03881 - peak code : 3256
# 03882 - peak code : 1434
# 03883 - peak code : 336
# 03884 - peak code : 942
# 03885 - peak code : 242
# 03886 - peak code : 536
# 03887 - peak code : 3489
# 03888 - peak code : 1895
# 03889 - peak code : 3019
# 03890 - peak code : 3549
# 03891 - peak code : 1829
# 03892 - peak code : 1834
# 03893 - peak code : 2004
# 03894 - peak code : 1590
# 03895 - peak code : 8
# 03896 - peak code : 4246
# 03897 - peak code : 3786
# 03898 - peak code : 344
# 03899 - peak code : 4002
# 03900 - peak code : 2107
# 03901 - peak code : 3621
# 03902 - peak code : 12
# 03903 - peak code : 761
# 03904 - peak code : 2872
# 03905 - peak code : 770
# 03906 - peak code : 1514
# 03907 - peak code : 2055
# 03908 - peak code : 22
# 03909 - peak code : 4020
# 03910 - peak code : 2315
# 03911 - peak code : 4233
# 03912 - peak code : 2656
# 03913 - peak code : 2524
# 03914 - peak code : 1495
# 03915 - peak code : 401
# 03916 - peak code : 4139
# 03917 - peak code : 2024
# 03918 - peak code : 41
# 03919 - peak code : 3913
# 03920 - peak code : 1747
# 03921 - peak code : 2559
# 03922 - peak code : 1394
# 03923 - peak code : 3914
# 03924 - peak code : 3550
# 03925 - peak code : 1620
# 03926 - peak code : 1622
# 03927 - peak code : 1621
# 03928 - peak code : 2535
# 03929 - peak code : 1894
# 03930 - peak code : 3733
# 03931 - peak code : 2242
# 03932 - peak code : 3714
# 03933 - peak code : 3920
# 03934 - peak code : 4435
# 03935 - peak code : 2340
# 03936 - peak code : 2888
# 03937 - peak code : 1832
# 03938 - peak code : 1308
# 03939 - peak code : 3882
# 03940 - peak code : 1714
# 03941 - peak code : 1777
# 03942 - peak code : 1800
# 03943 - peak code : 3782
# 03944 - peak code : 1828
# 03945 - peak code : 3067
# 03946 - peak code : 1761
# 03947 - peak code : 1473
# 03948 - peak code : 4038
# 03949 - peak code : 228
# 03950 - peak code : 3903
# 03951 - peak code : 3921
# 03952 - peak code : 4439
# 03953 - peak code : 1815
# 03954 - peak code : 1468
# 03955 - peak code : 4169
# 03956 - peak code : 3880
# 03957 - peak code : 3777
# 03958 - peak code : 2511
# 03959 - peak code : 879
# 03960 - peak code : 3780
# 03961 - peak code : 819
# 03962 - peak code : 446
# 03963 - peak code : 915
# 03964 - peak code : 1735
# 03965 - peak code : 548
# 03966 - peak code : 1737
# 03967 - peak code : 4510
# 03968 - peak code : 4580
# 03969 - peak code : 2039
# 03970 - peak code : 42
# 03971 - peak code : 44
# 03972 - peak code : 1428
# 03973 - peak code : 2564
# 03974 - peak code : 3893
# 03975 - peak code : 4243
# 03976 - peak code : 1452
# 03977 - peak code : 4451
# 03978 - peak code : 431
# 03979 - peak code : 4384
# 03980 - peak code : 421
# 03981 - peak code : 1427
# 03982 - peak code : 55
# 03983 - peak code : 56
# 03984 - peak code : 4425
# 03985 - peak code : 4676
# 03986 - peak code : 4247
# 03987 - peak code : 4672
# 03988 - peak code : 4677
# 03989 - peak code : 2902
# 03990 - peak code : 2983
# 03991 - peak code : 4089
# 03992 - peak code : 2002
# 03993 - peak code : 2982
# 03994 - peak code : 3405
# 03995 - peak code : 1439
# 03996 - peak code : 3785
# 03997 - peak code : 1060
# 03998 - peak code : 3999
# 03999 - peak code : 3781
# 04000 - peak code : 2618
# 04001 - peak code : 1287
# 04002 - peak code : 4237
# 04003 - peak code : 2525
# 04004 - peak code : 3416
# 04005 - peak code : 2093
# 04006 - peak code : 82
# 04007 - peak code : 4015
# 04008 - peak code : 1684
# 04009 - peak code : 1854
# 04010 - peak code : 4239
# 04011 - peak code : 1463
# 04012 - peak code : 4004
# 04013 - peak code : 420
# 04014 - peak code : 4379
# 04015 - peak code : 4380
# 04016 - peak code : 1715
# 04017 - peak code : 110
# 04018 - peak code : 3799
# 04019 - peak code : 111
# 04020 - peak code : 1863
# 04021 - peak code : 1990
# 04022 - peak code : 112
# 04023 - peak code : 113
# 04024 - peak code : 356
# 04025 - peak code : 2390
# 04026 - peak code : 2713
# 04027 - peak code : 120
# 04028 - peak code : 121
# 04029 - peak code : 4428
# 04030 - peak code : 1445
# 04031 - peak code : 4396
# 04032 - peak code : 4368
# 04033 - peak code : 4513
# 04034 - peak code : 126
# 04035 - peak code : 4511
# 04036 - peak code : 4436
# 04037 - peak code : 4450
# 04038 - peak code : 1822
# 04039 - peak code : 1787
# 04040 - peak code : 1537
# 04041 - peak code : 934
# 04042 - peak code : 1199
# 04043 - peak code : 1497
# 04044 - peak code : 1197
# 04045 - peak code : 1500
# 04046 - peak code : 3446
# 04047 - peak code : 1991
# 04048 - peak code : 3465
# 04049 - peak code : 1786
# 04050 - peak code : 176
# 04051 - peak code : 4053
# 04052 - peak code : 1499
# 04053 - peak code : 58
# 04054 - peak code : 1953
# 04055 - peak code : 209
# 04056 - peak code : 231
# 04057 - peak code : 2741
# 04058 - peak code : 2468
# 04059 - peak code : 4502
# 04060 - peak code : 3463
# 04061 - peak code : 4059
# 04062 - peak code : 2395
# 04063 - peak code : 114
# 04064 - peak code : 4027
# 04065 - peak code : 220
# 04066 - peak code : 893
# 04067 - peak code : 1619
# 04068 - peak code : 1426
# 04069 - peak code : 1116
# 04070 - peak code : 2162
# 04071 - peak code : 2839
# 04072 - peak code : 258
# 04073 - peak code : 1748
# 04074 - peak code : 198
# 04075 - peak code : 749
# 04076 - peak code : 2161
# 04077 - peak code : 1498
# 04078 - peak code : 4592
# 04079 - peak code : 4514
# 04080 - peak code : 4702
# 04081 - peak code : 205
# 04082 - peak code : 3938
# 04083 - peak code : 2145
# 04084 - peak code : 2156
# 04085 - peak code : 2295
# 04086 - peak code : 4242
# 04087 - peak code : 2265
# 04088 - peak code : 1997
# 04089 - peak code : 3962
# 04090 - peak code : 1574
# 04091 - peak code : 3916
# 04092 - peak code : 3016
# 04093 - peak code : 3902
# 04094 - peak code : 4391
# 04095 - peak code : 33
# 04096 - peak code : 3626
# 04097 - peak code : 3784
# 04098 - peak code : 2534
# 04099 - peak code : 4248
# 04100 - peak code : 57
# 04101 - peak code : 1291
# 04102 - peak code : 1125
# 04103 - peak code : 940
# 04104 - peak code : 1911
# 04105 - peak code : 1681
# 04106 - peak code : 3919
# 04107 - peak code : 1725
# 04108 - peak code : 3918
# 04109 - peak code : 1451
# 04110 - peak code : 3779
# 04111 - peak code : 1803
# 04112 - peak code : 3917
# 04113 - peak code : 714
# 04114 - peak code : 4241
# 04115 - peak code : 796
# 04116 - peak code : 2939
# 04117 - peak code : 4240
# 04118 - peak code : 1729
# 04119 - peak code : 4238
# 04120 - peak code : 3937
# 04121 - peak code : 1865
# 04122 - peak code : 390
# 04123 - peak code : 382
# 04124 - peak code : 1653
# 04125 - peak code : 3963
# 04126 - peak code : 212
# 04127 - peak code : 1504
# 04128 - peak code : 1496
# 04129 - peak code : 3798
# 04130 - peak code : 1831
# 04131 - peak code : 4272
# 04132 - peak code : 4236
# 04133 - peak code : 1168
# 04134 - peak code : 216
# 04135 - peak code : 3524
# 04136 - peak code : 2023
# 04137 - peak code : 3137
# 04138 - peak code : 2022
# 04139 - peak code : 1325
# 04140 - peak code : 225
# 04141 - peak code : 226
# 04142 - peak code : 2020
# 04143 - peak code : 2276
# 04144 - peak code : 2848
# 04145 - peak code : 1400
# 04146 - peak code : 3577
# 04147 - peak code : 3366
# 04148 - peak code : 2531
# 04149 - peak code : 1759
# 04150 - peak code : 3957
# 04151 - peak code : 1304
# 04152 - peak code : 3231
# 04153 - peak code : 2496
# 04154 - peak code : 243
# 04155 - peak code : 1326
# 04156 - peak code : 3206
# 04157 - peak code : 1567
# 04158 - peak code : 1011
# 04159 - peak code : 3783
# 04160 - peak code : 4501
# 04161 - peak code : 763
# 04162 - peak code : 1374
# 04163 - peak code : 2402
# 04164 - peak code : 2178
# 04165 - peak code : 3922
# 04166 - peak code : 3787
# 04167 - peak code : 2836
# 04168 - peak code : 2785
# 04169 - peak code : 2302
# 04170 - peak code : 1998
# 04171 - peak code : 2516
# 04172 - peak code : 256
# 04173 - peak code : 413
# 04174 - peak code : 2138
# 04175 - peak code : 2359
# 04176 - peak code : 4390
# 04177 - peak code : 3881
# 04178 - peak code : 311
# 04179 - peak code : 4273
# 04180 - peak code : 4274
# 04181 - peak code : 2747
# 04182 - peak code : 561
# 04183 - peak code : 90
# 04184 - peak code : 2520
# 04185 - peak code : 2003
# 04186 - peak code : 1652
# 04187 - peak code : 4432
# 04188 - peak code : 4374
# 04189 - peak code : 4399
# 04190 - peak code : 4429
# 04191 - peak code : 91
# 04192 - peak code : 4555
# 04193 - peak code : 274
# it took  4430.196 seconds

# %% [markdown]
# # <span style="color: indigo">Adjusting data type and values</span>

# %% [markdown]
# In the next block, we will adjust some of the data providing a more clear data

# %%
# create a copy of data frame in order to preserve the original data untouched
peaks_df = df.copy()

# arrange the columns names
peaks_df.columns = peaks_df.columns.str.replace(':', '')
peaks_df.columns = peaks_df.columns.str.replace(' ', '_')
peaks_df.columns = peaks_df.columns.str.replace('(', '')
peaks_df.columns = peaks_df.columns.str.replace(')', '')
keys = ['peak_code','name_of_peak','Elevation_feet','Elevation_meters','Continent','Country','State','Province',                      
        'Range/Region','Latitude','Longitude','Difficulty','Best_months_for_climbing',
        'Year_first_climbed','First_successful_climbers','Nearest_major_airport',
        'Convenient_Center','Volcanic_status','Most_recent_eruption']
peaks_df.index.name = "row_num"
peaks_df = peaks_df.reindex_axis(keys, axis=1)
peaks_df.columns = peaks_df.columns.str.lower()

# %% [markdown]
# >**elevation_feet/meters :**If both elevations are missing, then drop the peak record.

# %%
no_elevation_list = peaks_df[(peaks_df.elevation_feet .isnull()==True)&(peaks_df.elevation_meters.isnull()==True)].index.tolist()
peaks_df.drop(no_elevation_list,inplace=True)

# %% [markdown]
# >**elevation_feet/meters :** If only one of the elevations is given, then fill the missing data

# %%
f_t_m =0.3048 # meter = feet * 0.3048
peaks_df.elevation_feet = peaks_df.elevation_feet.str.replace(',', '')
peaks_df.elevation_meters = peaks_df.elevation_meters.str.replace(',', '')
peaks_df.elevation_feet = pd.to_numeric(peaks_df.elevation_feet,downcast='float', errors='coerce')
peaks_df.elevation_meters = pd.to_numeric(peaks_df.elevation_meters,downcast='float', errors='coerce')

# %%
null_meters = peaks_df.elevation_meters.isnull()
# 1st option using .loc
peaks_df.loc[null_meters, 'elevation_meters']=peaks_df.loc[null_meters, 'elevation_feet']*f_t_m
# 2nd option using where
# peaks_df.elevation_meters = peaks_df.elevation_feet.where(peaks_df.elevation_meters.isnull(),other = peaks_df.elevation_meters/f_t_m)*f_t_m
# peaks_df[['elevation_meters','elevation_feet']] = peaks_df[['elevation_meters','elevation_feet']].applymap(lambda x: '%.1f' % x)

# %% [markdown]
# >**country :** If a peak is listed with more than a single country, then use the first country.

# %%
peaks_df.country = peaks_df.country.str.split('/').str[0]
# peaks_df.country = peaks_df.country.map(lambda x: np.nan if x=='None' else x)

# %% [markdown]
# >**year_first_climbed :** if the date of the first climbing is recorded as an irregular date, then try to manipulate it so that only the year data is preserved.
# If the data is too obscure, then put None instead

# %%
# remove Nulls
null_first_climbed = peaks_df.year_first_climbed.loc[peaks_df.year_first_climbed.str.contains("Don't know|Unkown|Unclimbed|No Info|n/a|---|Unknow|Long|Hell of a long time ago|Na|Prehistoric|pre-history|unknon|no data|pre-written history|no idea|prehistoric|Not Sure|Ancient|Roman Times|Unkonwn|several|BC|B.C", case = False,na = False)==True]
peaks_df.loc[null_first_climbed.index, 'year_first_climbed'] = np.nan

# turn 197- or 197? to 1970 but not ?197 to 0197
peaks_df.year_first_climbed = peaks_df.year_first_climbed.str.replace(r'([0-9]{3,4})[\?\-]', r'\g<1>0')
# In addition to character escapes and backreferences as described above,
# \g will use the substring matched by the group named name, as defined by the (?P...) syntax. 
# \g uses the corresponding group number; \g<2> is therefore equivalent to \2, 
# but isn’t ambiguous in a replacement such as \g<2>0. \20 would be interpreted as a reference to group 20, 
# not a reference to group 2 followed by the literal character '0'. 
# The backreference \g<0> substitutes in the entire substring matched by the RE.

# %%
regex = re.compile('([0-9]{3,4})')
peaks_df.year_first_climbed = pd.to_numeric(peaks_df.year_first_climbed.str.extract(regex, expand=False),downcast='integer', errors='coerce')

# %%
# changing 1916.0 to 1916 will turn type from float32 to object (string)
peaks_df.year_first_climbed = peaks_df.year_first_climbed.map(lambda x: str(x)[:-2] if ~np.isnan(x) else x)

# %%
# peaks_df.year_first_climbed = pd.to_datetime(peaks_df.year_first_climbed,format = '%Y', errors = 'raise')

# %% [markdown]
# >Update other columns type

# %%
peaks_df.latitude = pd.to_numeric(peaks_df.latitude,downcast='float', errors='coerce')
peaks_df.longitude = pd.to_numeric(peaks_df.longitude,downcast='float', errors='coerce')
peaks_df.country = peaks_df.country.astype(str)

# %%
peaks_df.country = peaks_df.country.map(lambda x:np.nan if x=='None' else x)

# %%
peaks_df.difficulty = peaks_df.difficulty.str.replace('Walk up', 'Walk Up')
peaks_df.difficulty = peaks_df.difficulty.str.replace('Basic Snow/Ice climb', 'Basic Snow/Ice Climb')

# %% [markdown]
# ### <span style="color: indigo">Exporting to CSV file called "peaks.csv"</span>

# %%
peaks_df.to_csv('peaks.csv', encoding='utf-8')
